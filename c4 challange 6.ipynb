# %% [markdown]
# # CHALLANGE 6

# %%
#TASK 1
import pandas as pd
import numpy as np

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as sql

# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data=pd.read_csv(r'C:\Users\User\Downloads\DS1_C4_S6_House_Prices_Data_Challenge (2).csv')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#task conrener area of least 6000 and save it in new stable
corner_data= data[(data['LotArea']>=6000)&(data['LotConfig']=='Corner')]

# %%
from sqlalchemy import create_engine

# %%
eng=create_engine("mysql+pymysql://root:12345678@localhost/house")
corner_data.to_sql('corner_dataa',eng,index=False)
# Out:
# 241

# %%
#task2 1 story and 1 family and flat roof 
data[(data['HouseStyle']=='1Story')&(data['BldgType']== '1Fam')&(data['RoofStyle']=='Flat')]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 153    154          20       RL          NaN    13500   Pave   NaN      Reg
# 271    272          20       RL         73.0    39104   Pave   NaN      IR1
# 457    458          20       RL          NaN    53227   Pave   NaN      IR1
# 466    467          20       RL         85.0    10628   Pave   NaN      Reg
# 588    589          20       RL         65.0    25095   Pave   NaN      IR1
# 888    889          20       RL         95.0    15865   Pave   NaN      IR1
# 934    935          20       RL        313.0    27650   Pave   NaN      IR2
# 1000  1001          20       RL         74.0    10206   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 153          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 271          Low    AllPub  ...        0    NaN   NaN         NaN       0
# ...

# %%
#task 3 caculate no of town houses
df_2=data[data['BldgType']=='Twnhs']
y=df_2.groupby(['HouseStyle'])['Id'].count()

# %%
y=y.reset_index()

# %%
y
# Out:
#   HouseStyle  Id
# 0     1Story   5
# 1     2Story  33
# 2     SFoyer   4
# 3       SLvl   1

# %%
#task 4 get3+bedroom cemnt bed
data[(data['BedroomAbvGr']>=3)&(data['Exterior1st']=='CemntBd')]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 108    109          50       RM         85.0     8500   Pave   NaN      Reg
# 196    197          20       RL         79.0     9416   Pave   NaN      Reg
# 261    262          60       RL         69.0     9588   Pave   NaN      IR1
# 278    279          20       RL        107.0    14450   Pave   NaN      Reg
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 305    306          20       RL         80.0    10386   Pave   NaN      Reg
# 316    317          60       RL         94.0    13005   Pave   NaN      IR1
# 344    345         160       RM         36.0     2592   Pave   NaN      Reg
# 349    350          60       RL         56.0    20431   Pave   NaN      IR2
# 357    358         120       RM         44.0     4224   Pave   NaN      Reg
# ...

# %%
#task 5 get data with 2 cars with  garage area >=500
car= data[(data['GarageCars']==2)&(data['GarageArea']>=500)]

# %%
car
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
# ...
