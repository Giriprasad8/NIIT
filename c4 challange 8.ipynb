# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\User\Downloads\DS1_C4_S8_Smartphones_Data_Challenge.csv')

# %%
df
# Out:
#     brand_name                                      model   price  avg_rating  \
# 0        apple                            Apple iPhone 11   38999         7.3
# 1        apple                    Apple iPhone 11 (128GB)   46999         7.5
# 2        apple                    Apple iPhone 11 Pro Max  109900         7.7
# 3        apple                            Apple iPhone 12   51999         7.4
# 4        apple                    Apple iPhone 12 (128GB)   55999         7.5
# ..         ...                                        ...     ...         ...
# 975     xiaomi                    Xiaomi Redmi Note 9 Pro   13999         7.5
# 976     xiaomi  Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)   14439         7.7
# 977     xiaomi                Xiaomi Redmi Note 9 Pro Max   16490         8.0
# 978        zte                               ZTE Axon 30S   19999         8.2
# 979        zte                       ZTE Axon 40 Ultra 5G   61990         8.9
#
# ...

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv(r'C:\Users\User\Downloads\DS1_C4_S8_Smartphones_Data_Challenge.csv')

# Extract the specified columns
selected_columns = ['price', 'avg_rating', 'processor_speed', 'battery_capacity', 'ram_capacity', 
                    'internal_memory', 'screen_size', 'num_rear_cameras', 'os', 'resolution_height', 
                    'resolution_width']

df_selected = df[selected_columns]

# %%
df_selected
# Out:
#       price  avg_rating  processor_speed  battery_capacity  ram_capacity  \
# 0     38999         7.3             2.65            3110.0             4
# 1     46999         7.5             2.65            3110.0             4
# 2    109900         7.7             2.65            3500.0             4
# 3     51999         7.4             3.10               NaN             4
# 4     55999         7.5             3.10               NaN             4
# ..      ...         ...              ...               ...           ...
# 975   13999         7.5             2.30            5020.0             4
# 976   14439         7.7             2.30            5020.0             4
# 977   16490         8.0             2.30            5020.0             6
# 978   19999         8.2             3.20            4200.0             6
# 979   61990         8.9             3.00            5000.0             8
#
#      internal_memory  screen_size  num_rear_cameras       os  \
# ...

# %%
import pandas as pd
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

import pandas as pd

# Read the dataset
df = pd.read_csv(r'C:\Users\User\Downloads\DS1_C4_S8_Smartphones_Data_Challenge.csv')

# Extract the specified columns
selected_columns = ['price', 'avg_rating', 'processor_speed', 'battery_capacity', 'ram_capacity', 
                    'internal_memory', 'screen_size', 'num_rear_cameras', 'os', 'resolution_height', 
                    'resolution_width']

df_selected = df[selected_columns]

# Check for null values
null_values = df_selected.isnull().sum()

# Print the number of null values in each column
print("Null values in each column:")
print(null_values)

# Drop rows with null values
df_selected.dropna(inplace=True)
# Out:
# Null values in each column:
# price                  0
# avg_rating           101
# processor_speed       42
# battery_capacity      11
# ram_capacity           0
# internal_memory        0
# screen_size            0
# num_rear_cameras       0
# os                    14
# resolution_height      0
# resolution_width       0
# dtype: int64

# %%
df_selected.head()
# Out:
#      price  avg_rating  processor_speed  battery_capacity  ram_capacity  \
# 0    38999         7.3             2.65            3110.0             4
# 1    46999         7.5             2.65            3110.0             4
# 2   109900         7.7             2.65            3500.0             4
# 11   62999         7.9             3.22            3240.0             4
# 12   72999         7.9             3.22            3240.0             4
#
#     internal_memory  screen_size  num_rear_cameras   os  resolution_height  \
# 0                64          6.1                 2  ios               1792
# 1               128          6.1                 2  ios               1792
# 2                64          6.5                 3  ios               2688
# 11              128          6.1                 2  ios               2532
# 12              256          6.1                 2  ios               2532
#
#     resolution_width
# 0                828
# 1                828
# ...

# %%
df_selected.isnull().sum()
# Out:
# price                0
# avg_rating           0
# processor_speed      0
# battery_capacity     0
# ram_capacity         0
# internal_memory      0
# screen_size          0
# num_rear_cameras     0
# os                   0
# resolution_height    0
# resolution_width     0
# dtype: int64

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv(r'C:\Users\User\Downloads\DS1_C4_S8_Smartphones_Data_Challenge.csv')

# Extract the specified columns
selected_columns = ['price', 'avg_rating', 'processor_speed', 'battery_capacity', 'ram_capacity', 
                    'internal_memory', 'screen_size', 'num_rear_cameras', 'os', 'resolution_height', 
                    'resolution_width']

df_selected = df[selected_columns]


# Convert columns to the correct data types if needed
# For example, if 'os' is intended to be categorical, we can convert it to object data type
df_selected['os'] = df_selected['os'].astype('str')

# Convert specified columns to float data type
columns_to_convert = ['price', 'avg_rating', 'processor_speed', 'battery_capacity', 'ram_capacity', 
                      'internal_memory', 'screen_size', 'num_rear_cameras', 'resolution_height', 
                      'resolution_width']

for col in columns_to_convert:
    df_selected[col] = df_selected[col].astype(float)

# %%
df_selected.dtypes
# Out:
# price                float64
# avg_rating           float64
# processor_speed      float64
# battery_capacity     float64
# ram_capacity         float64
# internal_memory      float64
# screen_size          float64
# num_rear_cameras     float64
# os                    object
# resolution_height    float64
# resolution_width     float64
# dtype: object

# %%
import pandas as pd

# Load dataset
data = pd.read_csv(r'C:\Users\User\Downloads\DS1_C4_S8_Smartphones_Data_Challenge.csv')  # Replace with path to your CSV file

# Filter data for Android and iOS
data_android = data[data['os'] == "Android"].aggreate
data_ios = data[data['os'] == "IOS"]

# Print the first few rows of filtered data
print("Android Data:")
print(data_android.head())

print("\niOS Data:")
print(data_ios.head())
# Out:
# Android Data:
# Empty DataFrame
# Columns: [brand_name, model, price, avg_rating, 5G_or_not, processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width]
# Index: []
#
# [0 rows x 22 columns]
#
# iOS Data:
# Empty DataFrame
# Columns: [brand_name, model, price, avg_rating, 5G_or_not, processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Exclude 'os' column from the DataFrame
numeric_columns = df_selected.drop(columns=['os'])

# Calculate mean, median, and mode
mean_values = numeric_columns.mean()
median_values = numeric_columns.median()
mode_values = numeric_columns.mode().iloc[0]  # Mode may have multiple values, so we take the first one

# Print the calculated statistics
print("Mean:")
print(mean_values)
print("\nMedian:")
print(median_values)
print("\nMode:")
print(mode_values)
# Out:
# Mean:
# price                32520.504082
# avg_rating               7.825825
# processor_speed          2.427217
# battery_capacity      4817.748194
# ram_capacity             6.560204
# internal_memory        141.036735
# screen_size              6.536765
# num_rear_cameras         2.814286
# resolution_height     2214.663265
# resolution_width      1075.852041
# dtype: float64
#
# Median:
# price                19994.50
# avg_rating               8.00
# processor_speed          2.30
# battery_capacity      5000.00
# ram_capacity             6.00
# internal_memory        128.00
# screen_size              6.58
# num_rear_cameras         3.00
# resolution_height     2400.00
# resolution_width      1080.00
# dtype: float64
#
# Mode:
# price                14999.0
# avg_rating               8.4
# processor_speed          2.0
# battery_capacity      5000.0
# ram_capacity             8.0
# internal_memory        128.0
# screen_size              6.5
# num_rear_cameras         3.0
# ...

# %%
# Exclude 'os' column from the DataFrame
numeric_columns = df_selected.drop(columns=['os'])

# Calculate standard deviation
std_values = numeric_columns.std()

# Calculate coefficient of variation
cv_values = std_values / mean_values

# Print the calculated statistics
print("Standard Deviation:")
print(std_values)
print("\nCoefficient of Variation:")
print(cv_values)
# Out:
# Standard Deviation:
# price                39531.812669
# avg_rating               0.740285
# processor_speed          0.464090
# battery_capacity      1009.540054
# ram_capacity             2.744378
# internal_memory        107.134516
# screen_size              0.349162
# num_rear_cameras         0.776441
# resolution_height      516.484254
# resolution_width       290.164931
# dtype: float64
#
# Coefficient of Variation:
# price                1.215597
# avg_rating           0.094595
# processor_speed      0.191202
# battery_capacity     0.209546
# ram_capacity         0.418337
# internal_memory      0.759621
# screen_size          0.053415
# num_rear_cameras     0.275893
# resolution_height    0.233211
# resolution_width     0.269707
# dtype: float64

# %%
# Exclude 'os' column from the DataFrame
numeric_columns = df_selected.drop(columns=['os'])

# Calculate kurtosis
kurtosis_values = numeric_columns.kurtosis()

# Print the calculated kurtosis values
print("Kurtosis:")
print(kurtosis_values)
# Out:
# Kurtosis:
# price                 79.191922
# avg_rating            -0.300681
# processor_speed       -0.666667
# battery_capacity     154.678982
# ram_capacity           0.995368
# internal_memory       24.315641
# screen_size           17.475291
# num_rear_cameras       0.114688
# resolution_height      1.000787
# resolution_width       6.422227
# dtype: float64

# %%
# Exclude 'os' column from the DataFrame
numeric_columns = df_selected.drop(columns=['os'])

# Create box plots for all numeric columns
numeric_columns.boxplot(figsize=(20, 11))
plt.title('Box Plot of Numeric Columns (Excluding "os")')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #To compare the analysis of both Android and iOS operating systems based on the provided dataset, you would typically assess various statistical measures and visualizations for each OS separately and then compare the findings. Here's how you could interpret the comparison:
#
# 1. **Price Analysis:**
#    - Android: The median price of Android smartphones is higher compared to iOS devices, indicating that Android devices may cover a wider range of price points.
#    - iOS: The distribution of prices for iOS devices appears to be slightly more skewed towards higher values, with a lower median compared to Android.
#
# 2. **Rating Analysis:**
#    - Android: The average rating for Android smartphones is higher compared to iOS devices, suggesting that users may generally rate Android devices more positively.
#    - iOS: While the average rating for iOS devices is slightly lower than Android, it's important to note that iOS devices still maintain a high level of user satisfaction.
#
# 3. **Feature Analysis (e.g., processor speed, battery capacity, etc.):**
#    - You can conduct similar comparisons for each feature, looking at measures like mean, median, and mode to understand the distribution and central tendency for both OS.
#    - Analyze any notable differences or similarities between Android and iOS devices in terms of hardware specifications.
#
# 4. **Visualization Comparison (e.g., Box Plots):**
#    - Comparing box plots for numerical features between Android and iOS can provide insights into the distribution and spread of values for each OS.
#    - Look for any variations in the distribution of features between Android and iOS devices.
#
# 5. **Summary:**
#    - Provide a summary of the key findings, highlighting any significant differences or similarities observed between Android and iOS devices.
#    - Consider factors such as price range, user ratings, and hardware specifications when drawing conclusions.
#    - It's essential to interpret the results in the context of the dataset and consider any potential biases or limitations.
#
# Overall, comparing the analysis of Android and iOS devices allows for a comprehensive understanding of the differences and similarities between the two operating systems in terms of smartphone features and user perception.
